# %%
import numpy as np
import pandas as pd
import folium

# %%
df = pd.read_csv('pokemon-spawns.csv')
poke4000 = df.head(1000)
poke4000
# Out:
#                    s2_id     s2_token  num     name        lat         lng  \
# 0   -9185794522947256000  8085808cc6d   13   Weedle  37.793592 -122.408721
# 1   -9185794529389707000  8085808b51d   16   Pidgey  37.794746 -122.406420
# 2   -9185794529389707000  8085808b271   41    Zubat  37.794999 -122.404384
# 3   -9185794082713108000  808580f3587   16   Pidgey  37.795644 -122.407128
# 4   -9185794076270658000  808580f4b1d   60  Poliwag  37.795592 -122.406331
# ..                   ...          ...  ...      ...        ...         ...
# 995 -9182896186674119000  808fcc926c5   46    Paras  37.350137 -121.883077
# 996 -9182896197411537000  808fcc8f849   23    Ekans  37.350966 -121.889836
# 997 -9182896206001471000  808fcc8dfaf   84    Doduo  37.351095 -121.884144
# 998 -9182895795832095000  808fcced41b   16   Pidgey  37.351513 -121.877741
# 999 -9182896248951144000  808fcc83f01   19  Rattata  37.350988 -121.896772
#
#       encounter_ms    disppear_ms
# ...

# %%
a = np.random.randn()/150
b = np.random.randn()/15
lat = 37.320000 + a
lng = -122.000000 + b
m = folium.Map([lat, lng], tiles ='OpenStreetMap', zoom_start = 15)
for i in range(0, 1000):
    c = np.random.randn()/100
    d = np.random.randn()/100
    hai = poke4000.loc[i]['name']
    depan = "https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/"
    isi = str(poke4000.loc[i]['num'])
    belakang = ".png"
    pokemon = depan+isi+belakang
    gambar = '<img width= "250px" src="'+pokemon+'"/>'+'<center>'+hai+'</center>'
    Icon = folium.features.CustomIcon(pokemon, icon_size=(60,60))
    folium.Marker([poke4000.loc[i]['lat']+c, poke4000.loc[i]['lng']+d], icon=Icon, tooltip = gambar, popup=hai).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
